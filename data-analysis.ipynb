# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st

# %%
df = pd.read_json('./data/climate_no_co2/ssp585/clean/pos_generative_rand.json')
df.head()
# Out:
#    CO2_FFI_emissions  CO2_AFOLU_emissions  CO2_emissions  CH4_emissions  \
# 0           0.009506             0.297465       0.306970      19.019783
# 1           0.009506             0.302937       0.312443      18.915109
# 2           0.009510             0.308510       0.318020      18.889712
# 3           0.009510             0.314186       0.323696      19.121377
# 4           0.009514             0.319966       0.329480      19.509061
#
#    N2O_emissions  CO2_FFI_concentration  CO2_AFOLU_concentration  \
# 0       0.086022                      0                        0
# 1       0.087647                      0                        0
# 2       0.089303                      0                        0
# 3       0.090990                      0                        0
# 4       0.092709                      0                        0
#
#    CO2_concentration  CH4_concentration  N2O_concentration  ...  \
# 0         278.300000         729.200000         270.100000  ...
# ...

# %%
num_runs = np.max(df['run'])
start_year = np.min(df['year'])
end_year = np.max(df['year'])

num_runs, start_year, end_year
# Out:
# (10, 1750, 2100)

# %%
emissions = []

for i in range(1, num_runs + 1):
    for j in range(start_year, end_year + 1):
        co2_emissions = df.loc['year':j, 'run':i]['co2_emissions']
        emissions += co2_emissions

emissions
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 5
#       3 for i in range(1, num_runs + 1):
#       4     for j in range(start_year, end_year + 1):
# ----> 5         co2_emissions = df.loc['year':j, 'run':i]['co2_emissions']
#       6         emissions += co2_emissions
#       8 emissions
#
# File ~/opt/miniconda3/envs/group-project/lib/python3.12/site-packages/pandas/core/indexing.py:1185, in _LocationIndexer.__getitem__(self, key)
#    1183     if self._is_scalar_access(key):
#    1184         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1185     return self._getitem_tuple(key)
#    1186 else:
#    1187     # we by definition only have the 0th axis
#    1188     axis = self.axis or 0
#
# File ~/opt/miniconda3/envs/group-project/lib/python3.12/site-packages/pandas/core/indexing.py:1378, in _LocIndexer._getitem_tuple(self, tup)
# ...

# %%
co2_emissions = data['CO2_emissions']
np.percentile(co2_emissions, [5, 95])
# Out:
# array([  0.4179833 , 128.00288136])
