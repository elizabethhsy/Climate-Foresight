# %%
import numpy as np
import pandas as pd
# Out:
# /var/folders/8s/f0bh0b3s00l71cfdl94mjwyh0000gn/T/ipykernel_29037/1662815981.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
pd.options.display.max_rows = 4000

# %%
df = pd.read_csv("data/climate/pos_generative.csv", header=None)

# %%
df.iloc[0:351, 15:19]
# Out:
#             15             16             17             18
# 0     0.000000   0.000000e+00   0.000000e+00   0.000000e+00
# 1     0.000636  -1.330694e-05   8.302254e-06   4.119011e-07
# 2     0.001138  -3.379317e-05   5.176526e-05   6.236473e-06
# 3     0.001599  -3.491487e-05   1.660487e-04   3.929704e-05
# 4     0.002092   4.311695e-05   3.824439e-04   1.717446e-04
# 5     0.002653   3.066148e-04   7.171064e-04   6.211339e-04
# 6     0.003192   9.370024e-04   1.223886e-03   2.031206e-03
# 7     0.003708   2.314759e-03   2.304372e-03   6.326990e-03
# 8     0.004335   5.561079e-03   5.809489e-03   1.935603e-02
# 9     0.004921   1.451364e-02   1.838028e-02   5.906534e-02
# 10    0.005538   4.210443e-02   6.119086e-02   1.807563e-01
# 11    0.006202   1.299960e-01   1.986624e-01   5.548832e-01
# 12    0.006865   4.080942e-01   6.249555e-01   1.706345e+00
# 13    0.007540   1.275228e+00   1.928736e+00   5.250095e+00
# 14    0.008307   3.951120e+00   5.909295e+00   1.615250e+01
# ...

# %%
df.iloc[0:351, 15]
# Out:
# 0       0.000636
# 1       0.001138
# 2       0.001599
# 3       0.002092
# 4       0.002653
# 5       0.003192
# 6       0.003708
# 7       0.004335
# 8       0.004921
# 9       0.005538
# 10      0.006202
# 11      0.006865
# 12      0.007540
# 13      0.008307
# 14      0.009199
# 15      0.010375
# 16      0.011189
# 17      0.010633
# 18      0.011634
# 19      0.012733
# 20      0.013851
# 21      0.014992
# 22      0.016152
# 23      0.017333
# 24      0.018534
# 25      0.019756
# 26      0.021002
# 27      0.022271
# 28      0.023561
# 29      0.024873
# 30      0.026208
# 31      0.027571
# 32      0.028957
# 33      0.030368
# 34      0.031802
# 35      0.033262
# 36      0.034752
# 37      0.036269
# 38      0.037811
# 39      0.039380
# 40      0.040977
# 41      0.042606
# 42      0.044266
# 43      0.045954
# 44      0.047671
# 45      0.049417
# 46      0.051197
# 47      0.053010
# 48      0.054857
# 49      0.056739
# 50      0.058657
# 51      0.060609
# ...
